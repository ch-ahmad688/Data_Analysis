# %%
import pandas as pd

# %%
df = pd.read_csv("employee_salary_dataset_100_rows.csv")
print(df)
# Out:
#     Employee_ID    Name  Gender  Age Department  Experience_Years Education  \
# 0          1001     Ali    Male   33         HR                 8      BSCS
# 1          1002    Hira    Male   35         IT                13       BBA
# 2          1003    Zain    Male   36         HR                 6       MCS
# 3          1004    Amna  Female   24    Finance                 0       MBA
# 4          1005    Amna    Male   33      Sales                10      BSCS
# ..          ...     ...     ...  ...        ...               ...       ...
# 95         1096    Noor    Male   41  Marketing                15      BCom
# 96         1097    Umar    Male   32    Finance                 6       BBA
# 97         1098    Noor    Male   30         IT                 4      BCom
# 98         1099   Hamza    Male   38  Marketing                15       MBA
# 99         1100  Fatima  Female   34    Finance                10       MCS
#
#           City  Salary
# 0       Multan  133314
# ...

# %% [markdown]
# ### Total employees

# %%
df = pd.read_csv("employee_salary_dataset_100_rows.csv")
print(len(df))
# Out:
# 100

# %% [markdown]
# ### Average salary

# %%
df = pd.read_csv("employee_salary_dataset_100_rows.csv")
print(df['Salary'].mean())
# Out:
# 132016.63

# %% [markdown]
# ### Highest salary

# %%
df = pd.read_csv("employee_salary_dataset_100_rows.csv")
print(df['Salary'].min())
# Out:
# 32465

# %% [markdown]
# ### Lowest salary

# %%
df = pd.read_csv("employee_salary_dataset_100_rows.csv")
print(df['Salary'].max())
# Out:
# 229319

# %% [markdown]
# ### Male employees

# %%
df = pd.read_csv("employee_salary_dataset_100_rows.csv")
male_count = (df["Gender"] == "Male").sum()
print(male_count)
# Out:
# 56

# %% [markdown]
# ### Female employees

# %%
df = pd.read_csv("employee_salary_dataset_100_rows.csv")
female_count = (df["Gender"] == "Female").sum()
print(female_count)
# Out:
# 44

# %% [markdown]
# ### Department-wise average salary

# %%
df = pd.read_csv("employee_salary_dataset_100_rows.csv")

average_salary = df.groupby("Department")["Salary"].mean()

print(average_salary)
# Out:
# Department
# Finance      133480.333333
# HR           124906.142857
# IT           125598.133333
# Marketing    133645.500000
# Sales        146520.125000
# Name: Salary, dtype: float64

# %% [markdown]
# ### Department-wise employee

# %%
df = pd.read_csv("employee_salary_dataset_100_rows.csv")

Employee = df["Department"].value_counts()

print(Employee)
# Out:
# Department
# HR           28
# Finance      21
# Marketing    20
# Sales        16
# IT           15
# Name: count, dtype: int64

# %% [markdown]
# ### Experience aur salary relationship

# %%
df = pd.read_csv("employee_salary_dataset_100_rows.csv")

comparison = df[
    (df["Experience_Years"] > 13) &
    (df["Salary"] > 200000)
]

print(comparison)
# Out:
#     Employee_ID    Name  Gender  Age Department  Experience_Years Education  \
# 12         1013  Hassan  Female   38         HR                14       BBA
# 21         1022    Sara    Male   45    Finance                15      BCom
# 29         1030  Ayesha    Male   38         HR                14       MBA
# 60         1061  Fatima  Female   43  Marketing                14       MCS
# 65         1066    Sara    Male   36         HR                14      BSCS
# 66         1067    Amna    Male   44  Marketing                14       MBA
# 67         1068    Umar  Female   38      Sales                14       MBA
# 68         1069    Amna  Female   40      Sales                15      BSCS
# 71         1072    Zain  Female   42         HR                14       MCS
# 85         1086   Hamza  Female   38         HR                14      BCom
# 86         1087    Hira  Female   44  Marketing                15       MBA
# ...

# %% [markdown]
# ### Top 10 highest-paid employees

# %%
df = pd.read_csv("employee_salary_dataset_100_rows.csv")
print(df.nlargest(10,"Salary")[["Name","Salary"]])
# Out:
#       Name  Salary
# 95    Noor  229319
# 91    Noor  224685
# 86    Hira  224272
# 68    Amna  218998
# 66    Amna  216314
# 65    Sara  216265
# 21    Sara  215410
# 67    Umar  213554
# 85   Hamza  212270
# 29  Ayesha  211824

# %% [markdown]
# ### Salary > 200000 employees

# %%
df = pd.read_csv("employee_salary_dataset_100_rows.csv")
salary = df[df['Salary']>200000]
print(salary)
# Out:
#     Employee_ID    Name  Gender  Age Department  Experience_Years Education  \
# 12         1013  Hassan  Female   38         HR                14       BBA
# 21         1022    Sara    Male   45    Finance                15      BCom
# 29         1030  Ayesha    Male   38         HR                14       MBA
# 33         1034   Bilal  Female   43         HR                13       BBA
# 60         1061  Fatima  Female   43  Marketing                14       MCS
# 65         1066    Sara    Male   36         HR                14      BSCS
# 66         1067    Amna    Male   44  Marketing                14       MBA
# 67         1068    Umar  Female   38      Sales                14       MBA
# 68         1069    Amna  Female   40      Sales                15      BSCS
# 71         1072    Zain  Female   42         HR                14       MCS
# 85         1086   Hamza  Female   38         HR                14      BCom
# ...

# %% [markdown]
# ### Education-wise average salary

# %%
df = pd.read_csv("employee_salary_dataset_100_rows.csv")

average_salary = df.groupby("Education")["Salary"].mean()

print(average_salary)
# Out:
# Education
# BBA     138830.117647
# BCom    139799.000000
# BSCS    131225.925926
# MBA     153212.550000
# MCS     109085.000000
# Name: Salary, dtype: float64

# %% [markdown]
# ### City-wise average salary

# %%
df = pd.read_csv("employee_salary_dataset_100_rows.csv")

average_salary = df.groupby("City")["Salary"].mean()

print(average_salary)
# Out:
# City
# Faisalabad    164195.411765
# Islamabad     138155.055556
# Karachi       114954.800000
# Lahore        105972.000000
# Multan        132888.000000
# Sahiwal       124482.090909
# Name: Salary, dtype: float64

# %% [markdown]
# ### Department maximum salary

# %%
df = pd.read_csv("employee_salary_dataset_100_rows.csv")

average_salary = df.groupby("Department")["Salary"].max()

print(average_salary)
# Out:
# Department
# Finance      215410
# HR           216265
# IT           224685
# Marketing    229319
# Sales        218998
# Name: Salary, dtype: int64

# %% [markdown]
# ### Department minimum salary

# %%
df = pd.read_csv("employee_salary_dataset_100_rows.csv")

average_salary = df.groupby("Department")["Salary"].min()

print(average_salary)
# Out:
# Department
# Finance      43848
# HR           32465
# IT           43873
# Marketing    56245
# Sales        83294
# Name: Salary, dtype: int64

# %% [markdown]
# ### Employees salary in descending order

# %%
df = pd.read_csv("employee_salary_dataset_100_rows.csv")

sorted_salary = df.sort_values(by="Salary", ascending=False)

print(sorted_salary)
# Out:
#     Employee_ID    Name  Gender  Age Department  Experience_Years Education  \
# 95         1096    Noor    Male   41  Marketing                15      BCom
# 91         1092    Noor    Male   44         IT                15      BSCS
# 86         1087    Hira  Female   44  Marketing                15       MBA
# 68         1069    Amna  Female   40      Sales                15      BSCS
# 66         1067    Amna    Male   44  Marketing                14       MBA
# ..          ...     ...     ...  ...        ...               ...       ...
# 3          1004    Amna  Female   24    Finance                 0       MBA
# 88         1089   Usman  Female   29         HR                 0       MCS
# 59         1060  Hassan  Female   26         HR                 0       MCS
# 79         1080  Ayesha    Male   24         HR                 0       MCS
# 45         1046    Zain  Female   23         HR                 0      BCom
#
#           City  Salary
# 95   Islamabad  229319
# ...

# %% [markdown]
# ### Experience > 10 years employees

# %%
df = pd.read_csv("employee_salary_dataset_100_rows.csv")
exprience = df[df['Experience_Years']>10]
print(exprience)
# Out:
#     Employee_ID    Name  Gender  Age Department  Experience_Years Education  \
# 1          1002    Hira    Male   35         IT                13       BBA
# 8          1009   Hamza  Female   35    Finance                11       BBA
# 12         1013  Hassan  Female   38         HR                14       BBA
# 13         1014    Noor  Female   41         HR                13       BBA
# 15         1016  Hassan    Male   41    Finance                12      BCom
# 21         1022    Sara    Male   45    Finance                15      BCom
# 27         1028   Ahmed    Male   40      Sales                13       MCS
# 29         1030  Ayesha    Male   38         HR                14       MBA
# 33         1034   Bilal  Female   43         HR                13       BBA
# 47         1048   Kiran    Male   36         IT                11       MBA
# 54         1055    Hira    Male   40      Sales                13      BCom
# ...

# %% [markdown]
# ### Salary median aur standard deviation

# %%
df = pd.read_csv("employee_salary_dataset_100_rows.csv")
print(df['Salary'].std())
# Out:
# 54870.29947943357

# %%
df = pd.read_csv("employee_salary_dataset_100_rows.csv")
print(df['Salary'].median())
# Out:
# 133185.0

# %% [markdown]
# ### Salary range (Min-Max)

# %%
print("Salary Range From :")
print(df["Salary"].min(), df["Salary"].max())
# Out:
# Salary Range From :
# 32465 229319

# %% [markdown]
# ### Highest paid employee in each department

# %%
highest_paid = (
    df.sort_values(by="Salary", ascending=False)
      .drop_duplicates(subset="Department")
)

print(highest_paid[["Department", "Name", "Salary"]])
# Out:
#    Department  Name  Salary
# 95  Marketing  Noor  229319
# 91         IT  Noor  224685
# 68      Sales  Amna  218998
# 65         HR  Sara  216265
# 21    Finance  Sara  215410

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("employee_salary_dataset_100_rows.csv")

level = np.where(df["Experience_Years"] >= 5, "Senior", "Junior")

df.insert(5, "Level", level)

df.to_csv("employee_salary_dataset_updated.csv", index=False)

print("CSV file successfully updated!")
# Out:
# CSV file successfully updated!
