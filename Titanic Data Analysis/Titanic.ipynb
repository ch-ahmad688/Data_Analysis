# %%
import pandas as pd

# %%
df = pd.read_csv("Titanic_Dataset_100_Rows.csv")
print(df.head(10))
# Out:
#    PassengerId  Survived  Pclass          Name     Sex  Age  SibSp  Parch  \
# 0            1         1       2  Zainab Malik    male   15      0      2
# 1            2         1       3     Ali Aslam    male   27      3      0
# 2            3         0       1     Sana Noor    male   37      1      0
# 3            4         1       1    Hina Tariq    male   35      0      2
# 4            5         1       2    Noman Noor  female   26      0      0
# 5            6         0       3   Kamran Raza    male   60      2      0
# 6            7         1       3  Ayesha Tariq  female   23      1      0
# 7            8         0       3      Sara Ali    male    6      2      1
# 8            9         1       2   Aliya Malik  female   35      1      0
# 9           10         1       2    Amina Shah  female   48      1      0
#
#      Fare Embarked
# 0   54.68        S
# 1   57.76        C
# 2  115.17        C
# 3   58.92        S
# 4   81.72        C
# 5   48.83        S
# ...

# %%
df = pd.read_csv("Titanic_Dataset_100_Rows.csv")
Total_SibSp = df["SibSp"].sum()
Total_Parch = df["Parch"].sum()
Total_Passengers = Total_SibSp + Total_Parch
print(Total_Passengers)
# Out:
# 261

# %%
df = pd.read_csv("Titanic_Dataset_100_Rows.csv")
Total_Survive = df['Survived'].sum()
print(Total_Survive)
Survive_Ratio = (Total_Survive /Total_Passengers) *100
print(Survive_Ratio)
# Out:
# 53
# 20.306513409961685

# %%
df = pd.read_csv("Titanic_Dataset_100_Rows.csv")
Total_UnSurvived = Total_Passengers - Total_Survive
print(Total_UnSurvived)
# Out:
# 208

# %%
df = pd.read_csv("Titanic_Dataset_100_Rows.csv")
print(df[df["Sex"]=="male"].value_counts().sum())
# Out:
# 55

# %%
df = pd.read_csv("Titanic_Dataset_100_Rows.csv")
print(df[df["Sex"]=="female"].value_counts().sum())
# Out:
# 45

# %%
female = df[df["Sex"] == "female"]

female_survived = female["Survived"].sum()
female_ratio = (female_survived / len(female)) * 100

print("Female Survival Rate:", round(female_ratio, 2), "%")
# Out:
# 34
# Female Survival Rate: 75.56 %

# %%
male = df[df["Sex"] == "male"]

male_survived = male["Survived"].sum()
male_ratio = (male_survived / len(male)) * 100

print("Male Survival Rate:", round(male_ratio, 2), "%")
# Out:
# Male Survival Rate: 34.55 %

# %%
df = pd.read_csv("Titanic_Dataset_100_Rows.csv")
print(df.nlargest(5, "Fare")[["Name", "Fare"]])
# Out:
#            Name    Fare
# 69  Imran Aslam  119.62
# 88    Ali Aslam  119.13
# 14  Amina Ahmed  117.51
# 25  Amina Iqbal  115.57
# 2     Sana Noor  115.17
